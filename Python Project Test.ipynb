# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as py
py.tools.set_credentials_file(username='Chemmy', api_key='7H9NNTTFmo9XN5JUAIT6')
import plotly.graph_objs as go

# %%
df=pd.read_csv('countymaps.txt', header=None, sep=',', names=['FIPS','STNAME','County name','TOT_POP','TOT_MALE','TOT_FEMALE','WA_MALE','WA_FEMALE','NHWA_MALE','NHWA_FEMALE','NHWhite_Alone','Not_NHWhite_Alone','MinorityMinority','MinorityPCT','Black','BlackPCT','Hispanic','HispanicPCT'])
data=df.iloc[:,2:]
df
# Out:
#      FIPS          STNAME          County name  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 0   37001  North Carolina      Alamance County   153920     73236       80684
# 1   37003  North Carolina     Alexander County    36853     18656       18197
# 2   37005  North Carolina     Alleghany County    10927      5440        5487
# 3   37007  North Carolina         Anson County    26351     13727       12624
# 4   37009  North Carolina          Ashe County    27097     13342       13755
# 5   37011  North Carolina         Avery County    17635      9630        8005
# 6   37013  North Carolina      Beaufort County    47507     22892       24615
# 7   37015  North Carolina        Bertie County    20653     10317       10336
# 8   37017  North Carolina        Bladen County    34915     16770       18145
# 9   37019  North Carolina     Brunswick County   112257     54877       57380
# 10  37021  North Carolina      Buncombe County   244490    117673      126817
# ...

# %%
df['County name']=df['County name'].str.replace(r"( County)", r"")
df['County name'].head()
# Out:
# 0     Alamance
# 1    Alexander
# 2    Alleghany
# 3        Anson
# 4         Ashe
# Name: County name, dtype: object

# %%
py.offline.init_notebook_mode(connected=True)
import plotly.figure_factory as ff
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
import plotly as py
py.tools.set_credentials_file(username='Chemmy', api_key='7H9NNTTFmo9XN5JUAIT6')
import pandas as pd
import plotly.graph_objs as go
py.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
values = df['TOT_POP'].tolist()
fips = df['FIPS'].tolist()

colorscale = [
    'rgb(193, 193, 193)',
    'rgb(239,239,239)',
    'rgb(195, 196, 222)',
    'rgb(144,148,194)',
    'rgb(101,104,168)',
    'rgb(65, 53, 132)'
]

# %%
values = df['TOT_POP'].tolist()
fips = df['FIPS'].tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips, values=values, scope=['North Carolina', 'South Carolina', 'Virginia'],
     binning_endpoints=[14000, 35000, 95000, 150000, 200000], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Population by County', title='North Carolina'
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# C:\Users\msc7850\AppData\Local\Continuum\anaconda3\envs\test1\lib\site-packages\pandas\core\frame.py:6211: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# ...

# %%
info=pd.read_csv('https://raw.githubusercontent.com/dam6063/education/master/data.csv', header=0, sep=',')

# %%
info
# Out:
#       grade  num_tested  pct_ccr  pct_glp school_code subgroup subject type  \
# 0       ALL        2436     77.3     83.9    4.90E+01      ALL     ALL  ALL
# 1       ALL        2513     76.0     84.6    4.90E+01      ALL     ALL  ALL
# 2       ALL        2330     77.0     84.6    4.90E+01      ALL     ALL  ALL
# 3       ALL        2340     75.7     84.3    4.90E+01      ALL     ALL  ALL
# 4       ALL        2309     71.5     81.6    4.90E+01      ALL     ALL  ALL
# 5       ALL         880     81.8     88.0    9.20E+01      ALL     ALL  ALL
# 6       ALL         909     83.8     89.3    9.20E+01      ALL     ALL  ALL
# 7       ALL         868     79.8     88.0    9.20E+01      ALL     ALL  ALL
# 8       ALL         852     79.2     87.1    9.20E+01      ALL     ALL  ALL
# 9       ALL         860     76.5     84.0    9.20E+01      ALL     ALL  ALL
# 10      ALL         126     77.0     84.9       10303      ALL     ALL  ALL
# ...

# %%
final=pd.merge(df,info, on=['County name'], how='left')
final
# Out:
#         FIPS          STNAME County name  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 0      37001  North Carolina    Alamance   153920     73236       80684
# 1      37001  North Carolina    Alamance   153920     73236       80684
# 2      37001  North Carolina    Alamance   153920     73236       80684
# 3      37001  North Carolina    Alamance   153920     73236       80684
# 4      37001  North Carolina    Alamance   153920     73236       80684
# 5      37001  North Carolina    Alamance   153920     73236       80684
# 6      37001  North Carolina    Alamance   153920     73236       80684
# 7      37001  North Carolina    Alamance   153920     73236       80684
# 8      37001  North Carolina    Alamance   153920     73236       80684
# 9      37001  North Carolina    Alamance   153920     73236       80684
# 10     37001  North Carolina    Alamance   153920     73236       80684
# 11     37001  North Carolina    Alamance   153920     73236       80684
# ...

# %%
final2 = pd.DataFrame(final.groupby('County name', as_index=False)['TOT_POP'].mean())
final2['mean_pop']=final2['TOT_POP']
final2= final2.drop('TOT_POP', axis=1)
final3= pd.merge(final, final2, on='County name', how='left')
final3
# Out:
#         FIPS          STNAME County name  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 0      37001  North Carolina    Alamance   153920     73236       80684
# 1      37001  North Carolina    Alamance   153920     73236       80684
# 2      37001  North Carolina    Alamance   153920     73236       80684
# 3      37001  North Carolina    Alamance   153920     73236       80684
# 4      37001  North Carolina    Alamance   153920     73236       80684
# 5      37001  North Carolina    Alamance   153920     73236       80684
# 6      37001  North Carolina    Alamance   153920     73236       80684
# 7      37001  North Carolina    Alamance   153920     73236       80684
# 8      37001  North Carolina    Alamance   153920     73236       80684
# 9      37001  North Carolina    Alamance   153920     73236       80684
# 10     37001  North Carolina    Alamance   153920     73236       80684
# 11     37001  North Carolina    Alamance   153920     73236       80684
# ...

# %%
final17 = final[final.year == 2017]

glp_17 = final17.groupby('County name')['pct_glp'].agg('mean')
fips17= final17.groupby('County name')['FIPS'].agg('unique')

mean_glp = glp_17.tolist()
fips = fips17.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips, values=mean_glp, scope=['North Carolina', 'Virginia'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Mean Percentage of Students with At-Grade Scores in 2017"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="1ed8baea-5d53-4cc2-8dd3-4d8bd65dcd78" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1ed8baea-5d53-4cc2-8dd3-4d8bd65dcd78", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [], "y": [], "type": "scatter", "uid": "f2417588-cf07-4845-8209-343d2b5b755d"}, {"fill": "toself", "fillcolor": "rgb(244,109,67)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "30 - 45", "x": [-80.31020099999999, -80.255872, -80.22500199999999, -80.17281899999999, -80.111565, -80.024355, -79.92519, -79.875884, -79.900627, -79.86479299999999, -79.848479, -79.92801761198079, -80.3208073604558, -80.31020099999999, null, -77.82844399999999, -77.6979559999999
# ...

# %%
final16 = final[final.year == 2016]

glp_16 = final16.groupby('County name')['pct_glp'].agg('mean')
fips16= final16.groupby('County name')['FIPS'].agg('unique')

mean_glp = glp_16.tolist()
fips = fips16.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips, values=mean_glp, scope=['North Carolina', 'Virginia'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Mean Percentage of Students with At-Grade Scores in 2016"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="9b8ee39a-21cd-44e1-b8f4-61423420af5d" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9b8ee39a-21cd-44e1-b8f4-61423420af5d", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [], "y": [], "type": "scatter", "uid": "86aab360-915d-404b-b4d4-aad177f9a950"}, {"fill": "toself", "fillcolor": "rgb(244,109,67)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "30 - 45", "x": [-80.31020099999999, -80.255872, -80.22500199999999, -80.17281899999999, -80.111565, -80.024355, -79.92519, -79.875884, -79.900627, -79.86479299999999, -79.848479, -79.92801761198079, -80.3208073604558, -80.31020099999999, null, -77.82844399999999, -77.6979559999999
# ...

# %%
final15 = final[final.year == 2015]

glp_15 = final15.groupby('County name')['pct_glp'].agg('mean')
fips15= final15.groupby('County name')['FIPS'].agg('unique')

mean_glp = glp_15.tolist()
fips = fips15.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips, values=mean_glp, scope=['North Carolina', 'Virginia'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Mean Percentage of Students with At-Grade Scores in 2015"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="85842711-00cf-414c-b979-15ab68382ce0" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("85842711-00cf-414c-b979-15ab68382ce0", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [], "y": [], "type": "scatter", "uid": "60c62a8a-f0e9-48df-bc05-87300ce04c14"}, {"fill": "toself", "fillcolor": "rgb(244,109,67)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "30 - 45", "x": [-80.31020099999999, -80.255872, -80.22500199999999, -80.17281899999999, -80.111565, -80.024355, -79.92519, -79.875884, -79.900627, -79.86479299999999, -79.848479, -79.92801761198079, -80.3208073604558, -80.31020099999999, null, -78.90199799999999, -78.494705, -78.2
# ...

# %%
final14 = final[final.year == 2014]

glp_14 = final14.groupby('County name')['pct_glp'].agg('mean')
fips14= final14.groupby('County name')['FIPS'].agg('unique')

mean_glp = glp_14.tolist()
fips = fips14.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips, values=mean_glp, scope=['North Carolina', 'Virginia'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Mean Percentage of Students with At-Grade Scores in 2014"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="014fccc9-2d63-45ab-8ce2-a3b3d2690083" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("014fccc9-2d63-45ab-8ce2-a3b3d2690083", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [], "y": [], "type": "scatter", "uid": "9674b746-ee8b-4acb-a04c-a5b7a57ae32b"}, {"fill": "toself", "fillcolor": "rgb(244,109,67)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "30 - 45", "x": [-80.31020099999999, -80.255872, -80.22500199999999, -80.17281899999999, -80.111565, -80.024355, -79.92519, -79.875884, -79.900627, -79.86479299999999, -79.848479, -79.92801761198079, -80.3208073604558, -80.31020099999999, null, -78.90199799999999, -78.494705, -78.2
# ...

# %%
final13 = final[final.year == 2013]

glp_13 = final13.groupby('County name')['pct_glp'].agg('mean')
fips13= final13.groupby('County name')['FIPS'].agg('unique')

mean_glp = glp_13.tolist()
fips = fips13.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips, values=mean_glp, scope=['North Carolina', 'Virginia'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Mean Percentage of Students with At-Grade Scores in 2013"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="b7d88ea3-4f52-452e-92d0-bc46ad2d02ad" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b7d88ea3-4f52-452e-92d0-bc46ad2d02ad", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [], "y": [], "type": "scatter", "uid": "78bc13b8-d995-4eb5-815c-66a69c3ef623"}, {"fill": "toself", "fillcolor": "rgb(244,109,67)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "30 - 45", "x": [-80.31020099999999, -80.255872, -80.22500199999999, -80.17281899999999, -80.111565, -80.024355, -79.92519, -79.875884, -79.900627, -79.86479299999999, -79.848479, -79.92801761198079, -80.3208073604558, -80.31020099999999, null, -77.32762199999999, -77.230583, -77.2
# ...

# %%
final17 = final[final.year == 2017]

ccr_17 = final17.groupby('County name')['pct_ccr'].agg('mean')
fips17= final17.groupby('County name')['FIPS'].agg('unique')

mean_ccr = ccr_17.tolist()
fips = fips17.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips, values=mean_ccr, scope=['North Carolina', 'South Carolina'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Mean Percentage of Students Above Grade Level, 2017"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="03a433c8-5c54-4565-a9b0-35b15a155188" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("03a433c8-5c54-4565-a9b0-35b15a155188", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [-77.82844399999999, -77.69795599999999, -77.53361, -77.52665999999999, -77.402614, -77.342418, -77.350369, -77.472286, -77.665131, -77.751339, -77.82844399999999, null, -77.8997732393968, -77.16966, -77.06644299999999, -77.13678999999999, -77.208468, -77.228565, -77.29825, -77.299599, -77.385975, -77.37693399999999, -77.44166299999999, -77.57138599999999, -77.55049799999999, -77.644367, -77.899524, -77.8997732393968, null, -76.405565, -76.353554, -76.380009, -76.353442, -76.170524, -76.062522, -76.011421, 
# ...

# %%
ccr_17[:10]
# Out:
# County name
# Alamance     42.444737
# Alexander    53.500000
# Alleghany    50.250000
# Anson        32.190000
# Ashe         59.260000
# Avery        51.691667
# Beaufort     44.150000
# Bertie       39.042857
# Bladen       37.353846
# Brunswick    48.800000
# Name: pct_ccr, dtype: float64

# %%
ccr_all = final.groupby('County name')['pct_ccr'].agg('mean')
fips_all= final.groupby('County name')['FIPS'].agg('unique')

mean_ccr = ccr_all.tolist()
fips = fips_all.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips_all, values=mean_ccr, scope=['North Carolina', 'SC'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Total Mean Percentage of Students Above Grade Level"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="d1a57185-442f-4c11-a52d-04d09b86e03d" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d1a57185-442f-4c11-a52d-04d09b86e03d", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [-80.31020099999999, -80.255872, -80.22500199999999, -80.17281899999999, -80.111565, -80.024355, -79.92519, -79.875884, -79.900627, -79.86479299999999, -79.848479, -79.92801761198079, -80.3208073604558, -80.31020099999999, null, -77.82844399999999, -77.69795599999999, -77.53361, -77.52665999999999, -77.402614, -77.342418, -77.350369, -77.472286, -77.665131, -77.751339, -77.82844399999999, null, -78.006551, -77.94240599999999, -77.891015, -77.644367, -77.55049799999999, -77.57138599999999, -77.44166299999999
# ...

# %%
glp_all = final.groupby('County name')['pct_glp'].agg('mean')
fips_all= final.groupby('County name')['FIPS'].agg('unique')

mean_glp = glp_all.tolist()
fips = fips_all.tolist()

colorscale = [
    'rgb(165,0,38)',
    'rgb(244,109,67)',
    'rgb(253,174,97)',
    'rgb(238,238,0)',
    'rgb(124,252,0)',
    'rgb(48,128,20)'
]

fig = ff.create_choropleth(
    fips=fips_all, values=mean_glp, scope=['North Carolina'],
     binning_endpoints=[30, 45, 60, 75], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Mean Passing by County', title="Total Mean Percentage of Students At Grade Level"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# <div id="8abdcac4-4682-4f82-94a9-bcbca7c973c9" style="height: 450px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8abdcac4-4682-4f82-94a9-bcbca7c973c9", [{"fill": "toself", "fillcolor": "rgb(165,0,38)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "< 30", "x": [], "y": [], "type": "scatter", "uid": "84ab80c4-4dbf-4b3c-9fde-29394debbcf3"}, {"fill": "toself", "fillcolor": "rgb(244,109,67)", "hoverinfo": "none", "line": {"color": "rgb(255,255,255)", "width": 0.5}, "mode": "lines", "name": "30 - 45", "x": [-80.31020099999999, -80.255872, -80.22500199999999, -80.17281899999999, -80.111565, -80.024355, -79.92519, -79.875884, -79.900627, -79.86479299999999, -79.848479, -79.92801761198079, -80.3208073604558, -80.31020099999999, null, -77.82844399999999, -77.6979559999999
# ...

# %%
total_mean_glp=final['pct_glp'].agg('mean')
total_mean_glp
# Out:
# 55.8563738683631

# %%
total_mean_ccr=final['pct_ccr'].agg('mean')
total_mean_ccr
# Out:
# 45.67730201451758

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
income = pd.read_table('Income.txt', header=None, sep='\t', names=['County name', 'median_income'])
income['median_income'] = income['median_income'].replace({' ': '', ',': ''}, regex=True)

# %%
mean_glp = pd.DataFrame(final.groupby(['County name', 'year'],as_index=False)['pct_glp'].agg('mean')).head()
mean_glp['mean_glp'] = mean_glp['pct_glp']
mean_glp = mean_glp.drop('pct_glp', axis=1)

# %%
final4 = pd.merge(final3, mean_glp, on=['County name', 'year'], how='left')
final4
# Out:
#         FIPS          STNAME County name  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 0      37001  North Carolina    Alamance   153920     73236       80684
# 1      37001  North Carolina    Alamance   153920     73236       80684
# 2      37001  North Carolina    Alamance   153920     73236       80684
# 3      37001  North Carolina    Alamance   153920     73236       80684
# 4      37001  North Carolina    Alamance   153920     73236       80684
# 5      37001  North Carolina    Alamance   153920     73236       80684
# 6      37001  North Carolina    Alamance   153920     73236       80684
# 7      37001  North Carolina    Alamance   153920     73236       80684
# 8      37001  North Carolina    Alamance   153920     73236       80684
# 9      37001  North Carolina    Alamance   153920     73236       80684
# 10     37001  North Carolina    Alamance   153920     73236       80684
# 11     37001  North Carolina    Alamance   153920     73236       80684
# ...

# %%
mean_ccr = pd.DataFrame(final.groupby(['County name', 'year'],as_index=False)['pct_ccr'].agg('mean')).head()
mean_ccr['mean_ccr'] = mean_ccr['pct_ccr']
mean_ccr = mean_ccr.drop('pct_ccr', axis=1)

# %%
final5 = pd.merge(final4, mean_ccr, on=['County name', 'year'], how='left')
final5
# Out:
#         FIPS          STNAME County name  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 0      37001  North Carolina    Alamance   153920     73236       80684
# 1      37001  North Carolina    Alamance   153920     73236       80684
# 2      37001  North Carolina    Alamance   153920     73236       80684
# 3      37001  North Carolina    Alamance   153920     73236       80684
# 4      37001  North Carolina    Alamance   153920     73236       80684
# 5      37001  North Carolina    Alamance   153920     73236       80684
# 6      37001  North Carolina    Alamance   153920     73236       80684
# 7      37001  North Carolina    Alamance   153920     73236       80684
# 8      37001  North Carolina    Alamance   153920     73236       80684
# 9      37001  North Carolina    Alamance   153920     73236       80684
# 10     37001  North Carolina    Alamance   153920     73236       80684
# 11     37001  North Carolina    Alamance   153920     73236       80684
# ...

# %%
more = pd.merge(income, final5, on='County name', how='left')
more['median_income'] == more['median_income'].astype(int)
more[12000:]
# Out:
#       County name median_income   FIPS          STNAME  TOT_POP  TOT_MALE  \
# 12000      Wilkes         33159  37193  North Carolina    69306     34191
# 12001      Wilkes         33159  37193  North Carolina    69306     34191
# 12002      Wilkes         33159  37193  North Carolina    69306     34191
# 12003      Wilkes         33159  37193  North Carolina    69306     34191
# 12004      Wilkes         33159  37193  North Carolina    69306     34191
# 12005      Wilkes         33159  37193  North Carolina    69306     34191
# 12006      Wilkes         33159  37193  North Carolina    69306     34191
# 12007      Wilkes         33159  37193  North Carolina    69306     34191
# 12008      Wilkes         33159  37193  North Carolina    69306     34191
# 12009      Wilkes         33159  37193  North Carolina    69306     34191
# 12010      Wilkes         33159  37193  North Carolina    69306     34191
# 12011      Wilkes         33159  37193  North Carolina    69306     34191
# ...

# %%
more['median']= more.median_income.astype(int)

# %%
more.groupby('County name')['median'].unique().head()
# Out:
# County name
# Alamance     [43043]
# Alexander    [40637]
# Alleghany    [35170]
# Anson        [33870]
# Ashe         [35951]
# Name: median, dtype: object

# %%
med_income = more['median'].unique()
fips_all= more.groupby('County name')['FIPS'].agg('unique')

median_income = med_income.tolist()
fips = fips_all.tolist()

colorscale = [
    'RGB(131,139,139)',
    ' RGB(69,139,116)',
    'RGB(102,205,170)',
    'RGB(118,238,198)',
    'RGB(127,255,212)',
    'RGB(0,255,255)'
]

fig = ff.create_choropleth(
    fips=fips_all, values=median_income, scope=['North Carolina', 'VA'],
     binning_endpoints=[25000, 32000, 40000, 50000], colorscale=colorscale,
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Median Income by County', title="Median Income"
)
py.offline.iplot(fig, filename='choropleth_nc_and_surr_states_outlines')
# Out:
# C:\Users\msc7850\AppData\Local\Continuum\anaconda3\envs\test1\lib\site-packages\pandas\core\frame.py:6211: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# ...

# %%
more = more.drop(['median_income'], axis=1)

# %%
more.describe(include='all')
# Out:
#        County name          FIPS          STNAME        TOT_POP  \
# count        12261  12261.000000           12261   12261.000000
# unique         100           NaN               1            NaN
# top           Wake           NaN  North Carolina            NaN
# freq           903           NaN           12261            NaN
# mean           NaN  37103.652149             NaN  268209.895115
# std            NaN     55.878061             NaN  305395.753749
# min            NaN  37001.000000             NaN    4338.000000
# 25%            NaN  37057.000000             NaN   61475.000000
# 50%            NaN  37101.000000             NaN  153920.000000
# 75%            NaN  37155.000000             NaN  324049.000000
# max            NaN  37199.000000             NaN  969031.000000
#
#              TOT_MALE     TOT_FEMALE        WA_MALE      WA_FEMALE  \
# count    12261.000000   12261.000000   12261.000000   12261.000000
# ...

# %%
sns.set()
plt.plot(more.groupby('year')['pct_ccr'].agg('mean'));
plt.xticks(np.arange(more['year'].min(), more['year'].max()+1));
plt.title('Percentage of Students Above Grade Level Over Time');

# %%
sns.set()
plt.plot(more.groupby('year')['pct_glp'].agg('mean'));
plt.xticks(np.arange(more['year'].min(), more['year'].max()+1));
plt.title('Percentage of Students at Grade Level Over Time');

# %%
sns.set()
plt.plot(more.groupby('year')['pct_glp'].agg('mean'));
plt.xticks(np.arange(more['year'].min(), more['year'].max()+1));
plt.ylim((0,100));

# %%
sns.set()
plt.plot(more.groupby('year')['pct_glp'].agg('mean'));
plt.plot(more.groupby('year')['pct_ccr'].agg('mean'));
plt.xticks(np.arange(more['year'].min(), more['year'].max()+1));
plt.ylim((0, 100))
# Out:
# (0, 100)

# %%
more[['pct_glp','pct_ccr']].corr()
# Out:
#           pct_glp   pct_ccr
# pct_glp  1.000000  0.986534
# pct_ccr  0.986534  1.000000

# %%
#sns.set()
#for i in more['County name']:
 #   x=more[more['County name']==i].year.unique()
  #  y=more[more['County name']==i].median
   # plt.plot(x,y);
#Don't have data by year so I can't plot this

# %%
corr = more[['TOT_POP','Black','Hispanic','num_tested','pct_ccr','pct_glp','year','mean_pop']].corr()
_, ax = plt.subplots(figsize=(13,10)) 

# graph correlation matrix
_ = sns.heatmap(corr, ax=ax,
                xticklabels=corr.columns.values,
                yticklabels=corr.columns.values,
                cmap='coolwarm')

# %%
corr
# Out:
#              TOT_POP     Black  Hispanic  num_tested   pct_ccr   pct_glp  \
# TOT_POP     1.000000  0.956646  0.979815    0.301153  0.149735  0.114497
# Black       0.956646  1.000000  0.962344    0.268687  0.079335  0.048690
# Hispanic    0.979815  0.962344  1.000000    0.303015  0.133268  0.100568
# num_tested  0.301153  0.268687  0.303015    1.000000  0.182835  0.148060
# pct_ccr     0.149735  0.079335  0.133268    0.182835  1.000000  0.986534
# pct_glp     0.114497  0.048690  0.100568    0.148060  0.986534  1.000000
# year        0.000502  0.000499  0.000334   -0.003235  0.071817  0.067302
# mean_pop    1.000000  0.956646  0.979815    0.301153  0.149735  0.114497
#
#                 year  mean_pop
# TOT_POP     0.000502  1.000000
# Black       0.000499  0.956646
# Hispanic    0.000334  0.979815
# num_tested -0.003235  0.301153
# pct_ccr     0.071817  0.149735
# pct_glp     0.067302  0.114497
# year        1.000000  0.000502
# mean_pop    0.000502  1.000000

# %%
info['school_number']=info['school_code'].astype(str).str[2:3]
charter=info[info['school_number'].str.isalpha()]
public=info[~info['school_number'].str.isalpha()]
public[~public['school_code'].str.isalnum()].count()
# Out:
# grade            10
# num_tested       10
# pct_ccr          10
# pct_glp          10
# school_code      10
# subgroup         10
# subject          10
# type             10
# year             10
# school_name      10
# district_name    10
# County name      10
# status           10
# school_number    10
# dtype: int64

# %%
prep=public[0:10]
prep
# Out:
#   grade  num_tested  pct_ccr  pct_glp school_code subgroup subject type  year  \
# 0   ALL        2436     77.3     83.9    4.90E+01      ALL     ALL  ALL  2017
# 1   ALL        2513     76.0     84.6    4.90E+01      ALL     ALL  ALL  2016
# 2   ALL        2330     77.0     84.6    4.90E+01      ALL     ALL  ALL  2015
# 3   ALL        2340     75.7     84.3    4.90E+01      ALL     ALL  ALL  2014
# 4   ALL        2309     71.5     81.6    4.90E+01      ALL     ALL  ALL  2013
# 5   ALL         880     81.8     88.0    9.20E+01      ALL     ALL  ALL  2017
# 6   ALL         909     83.8     89.3    9.20E+01      ALL     ALL  ALL  2016
# 7   ALL         868     79.8     88.0    9.20E+01      ALL     ALL  ALL  2015
# 8   ALL         852     79.2     87.1    9.20E+01      ALL     ALL  ALL  2014
# 9   ALL         860     76.5     84.0    9.20E+01      ALL     ALL  ALL  2013
#
#                    school_name                        district_name  \
# ...

# %%
notpublic= pd.merge(charter, prep, how='outer')

# %%
notpublic
# Out:
#     grade  num_tested  pct_ccr  pct_glp school_code subgroup subject type  \
# 0     ALL        1053     52.0     63.0      01B000      ALL     ALL  ALL
# 1     ALL        1068     53.7     65.4      01B000      ALL     ALL  ALL
# 2     ALL         835     56.6     68.6      01B000      ALL     ALL  ALL
# 3     ALL         797     56.3     68.6      01B000      ALL     ALL  ALL
# 4     ALL         744     51.5     62.1      01B000      ALL     ALL  ALL
# 5     ALL         876     57.2     66.7      01C000      ALL     ALL  ALL
# 6     ALL         878     58.5     69.0      01C000      ALL     ALL  ALL
# 7     ALL         817     62.4     72.6      01C000      ALL     ALL  ALL
# 8     ALL         794     54.2     65.7      01C000      ALL     ALL  ALL
# 9     ALL         755     50.7     64.1      01C000      ALL     ALL  ALL
# 10    ALL         464     63.4     72.4      01D000      ALL     ALL  ALL
# 11    ALL         526     71.9     79.1      01D000      ALL     ALL  ALL
# ...

# %%
pub_mean = public.groupby(['County name', 'year'])['pct_glp'].agg('mean')
not_mean = notpublic.groupby(['County name', 'year'])['pct_glp'].agg('mean')
    
not_mean.head()
# Out:
# County name  year
# Alamance     2013    68.833333
#              2014    71.600000
#              2015    72.766667
#              2016    71.166667
#              2017    67.366667
# Name: pct_glp, dtype: float64

# %%
pub_mean.head()
# Out:
# County name  year
# Alamance     2013    48.514706
#              2014    48.868571
#              2015    51.562857
#              2016    52.165714
#              2017    50.068571
# Name: pct_glp, dtype: float64

# %%
pub_all_mean=public.groupby('County name')['pct_glp'].agg('mean')
not_all_mean = notpublic.groupby('County name')['pct_glp'].agg('mean')

# %%
not_all_mean.head()
# Out:
# County name
# Alamance     70.346667
# Avery        30.350000
# Beaufort     59.100000
# Brunswick    71.820000
# Buncombe     73.486667
# Name: pct_glp, dtype: float64

# %%
pub_all_mean.head()
# Out:
# County name
# Alamance     50.245977
# Alexander    61.770000
# Alleghany    61.465000
# Anson        38.988889
# Ashe         64.864000
# Name: pct_glp, dtype: float64

# %%
from scipy.stats import ttest_ind, ttest_rel, f_oneway

# %% [markdown]
# We will begin by testing for a difference in the means, using a t-test for difference in means:

# %%
stat, p = ttest_ind(pub_all_mean, not_all_mean)

# %%
print('Statistics=%.3f, p=%.5f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
# Out:
# Statistics=-3.798, p=0.00021
# Different distributions (reject H0)

# %% [markdown]
# We can also test this again using an anova test, but this is unnecessary since we only have two groups...

# %%
stat1, p1 = f_oneway(pub_all_mean, not_all_mean)

# %%
print('F Score=%.3f, p=%.5f' % (stat1, p1))
alpha = 0.05
if p1 > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
# Out:
# F Score=14.427, p=0.00021
# Different distributions (reject H0)

# %%
notpubm=notpublic['pct_glp'].agg('mean')
pubm=public['pct_glp'].agg('mean')
pubm
# Out:
# 55.55139964264444

# %%
notpubm
# Out:
# 63.34903474903476

# %% [markdown]
# So not only can we conclude that there is a significant difference in mean percentage of students at grade level between public and charter schools for the years 2013-2017, we can suspect that nonpublic schools have the overall higher percentage.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
info['status'] = 'nonpublic'

# %%
info['status'] = (~info['school_number'].str.isalpha() & info['school_number'][10:])

# %%
info
# Out:
#       grade  num_tested  pct_ccr  pct_glp school_code subgroup subject type  \
# 0       ALL        2436     77.3     83.9    4.90E+01      ALL     ALL  ALL
# 1       ALL        2513     76.0     84.6    4.90E+01      ALL     ALL  ALL
# 2       ALL        2330     77.0     84.6    4.90E+01      ALL     ALL  ALL
# 3       ALL        2340     75.7     84.3    4.90E+01      ALL     ALL  ALL
# 4       ALL        2309     71.5     81.6    4.90E+01      ALL     ALL  ALL
# 5       ALL         880     81.8     88.0    9.20E+01      ALL     ALL  ALL
# 6       ALL         909     83.8     89.3    9.20E+01      ALL     ALL  ALL
# 7       ALL         868     79.8     88.0    9.20E+01      ALL     ALL  ALL
# 8       ALL         852     79.2     87.1    9.20E+01      ALL     ALL  ALL
# 9       ALL         860     76.5     84.0    9.20E+01      ALL     ALL  ALL
# 10      ALL         126     77.0     84.9       10303      ALL     ALL  ALL
# ...

# %%
#Would need to merge things 
mc = MultiComparison(info['pct_glp'], info['status'])
result = mc.tukeyhsd()
 
print(result)
print(mc.groupsunique)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower   upper  reject
# ---------------------------------------------
# False   True  -7.8232  -9.3687 -6.2777  True
# ---------------------------------------------
# [False  True]

# %% [markdown]
# So here we can reject the null hypothesis that there is no difference in mean between public and private schools, and we can also conclude that private schools have a mean pct_glp of around 7.8% higher through all years.

# %%
from scipy.stats import chisquare

# %%
from statsmodels.formula.api import ols

# %%
trial = pd.merge(more[['County name','median']], pd.DataFrame(pub_all_mean), on='County name', how='outer')

# %%
trial.head()
# Out:
#   County name  median    pct_glp
# 0    Alamance   43043  50.245977
# 1    Alamance   43043  50.245977
# 2    Alamance   43043  50.245977
# 3    Alamance   43043  50.245977
# 4    Alamance   43043  50.245977

# %%
trial.corr()
# Out:
#            median   pct_glp
# median   1.000000  0.531959
# pct_glp  0.531959  1.000000

# %%
trial2 = pd.merge(more[['County name','median']], pd.DataFrame(not_all_mean), on='County name', how='outer')
trial2.head()
# Out:
#   County name  median    pct_glp
# 0    Alamance   43043  70.346667
# 1    Alamance   43043  70.346667
# 2    Alamance   43043  70.346667
# 3    Alamance   43043  70.346667
# 4    Alamance   43043  70.346667

# %%
trial2.corr()
# Out:
#           median  pct_glp
# median   1.00000  0.43703
# pct_glp  0.43703  1.00000

# %%
pub_all_mean.plot(kind = "hist");
not_all_mean.plot(kind='hist', alpha=.8);
plt.legend(['Public', 'Not Public']);
plt.xlabel('Mean Percent at Grade Level');

# %%
pub_all_mean.sort_values()[:3]
# Out:
# County name
# Northampton    30.503226
# Edgecombe      35.856452
# Washington     36.344000
# Name: pct_glp, dtype: float64

# %%
not_all_mean.sort_values()[:3]
# Out:
# County name
# Warren    26.34
# Wayne     26.70
# Avery     30.35
# Name: pct_glp, dtype: float64

# %%
pub_all_mean.sort_values(ascending=False)[:3]
# Out:
# County name
# Polk        74.740000
# Yancey      69.371111
# Carteret    68.876250
# Name: pct_glp, dtype: float64

# %%
not_all_mean.sort_values(ascending=False)[:3]
# Out:
# County name
# Stanly      85.90
# Chatham     82.29
# Carteret    80.60
# Name: pct_glp, dtype: float64

# %%
fin= final3[['year','pct_glp']]
g = fin.groupby('year')['pct_glp'].mean()

# %%
g.plot.bar()

# %%
import seaborn as sns
sns.boxplot(x='year', y='pct_glp', data=fin)

# %%
sns.set_style('whitegrid')
sns.boxplot(x='year', y='pct_glp', hue='status', data=info);
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);
plt.title("Non-Public vs. Public School's Performance");

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
# grade            12261 non-null object
# num_tested       12261 non-null int64
# pct_ccr          12261 non-null float64
# pct_glp          12261 non-null float64
# school_code      12261 non-null object
# subgroup         12261 non-null object
# subject          12261 non-null object
# type             12261 non-null object
# year             12261 non-null int64
# school_name      12261 non-null object
# district_name    12261 non-null object
# County name      12261 non-null object
# status           12261 non-null bool
# school_number    12261 non-null object
# dtypes: bool(1), float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
final3[['TOT_POP','pct_glp']].corr()
# Out:
#           TOT_POP   pct_glp
# TOT_POP  1.000000  0.114497
# pct_glp  0.114497  1.000000

# %%
more.corr()
# Out:
#                        FIPS   TOT_POP  TOT_MALE  TOT_FEMALE   WA_MALE  \
# FIPS               1.000000  0.251569  0.255087    0.248230  0.270520
# TOT_POP            0.251569  1.000000  0.999909    0.999920  0.990489
# TOT_MALE           0.255087  0.999909  1.000000    0.999660  0.991433
# TOT_FEMALE         0.248230  0.999920  0.999660    1.000000  0.989441
# WA_MALE            0.270520  0.990489  0.991433    0.989441  1.000000
# WA_FEMALE          0.264242  0.990280  0.990907    0.989529  0.999604
# NHWA_MALE          0.272931  0.983973  0.985105    0.982750  0.998625
# NHWA_FEMALE        0.265599  0.984472  0.985224    0.983606  0.998186
# NHWhite_Alone      0.269220  0.984347  0.985285    0.983306  0.998522
# Not_NHWhite_Alone  0.220856  0.978452  0.977160    0.979502  0.941571
# Black              0.181621  0.956646  0.954397    0.958597  0.908990
# Hispanic           0.240912  0.979815  0.979658    0.979801  0.960058
# ...

# %%
pub_ccr=public.groupby('County name')['pct_ccr'].agg('mean')
not_ccr = notpublic.groupby('County name')['pct_ccr'].agg('mean')

# %%
trial3 = pd.merge(more[['County name','median']], pd.DataFrame(not_ccr), on='County name', how='outer')
trial3.corr()
# Out:
#            median   pct_ccr
# median   1.000000  0.493562
# pct_ccr  0.493562  1.000000

# %%
trial4 = pd.merge(more[['County name','median']], pd.DataFrame(pub_ccr), on='County name', how='outer')
trial4.corr()
# Out:
#            median   pct_ccr
# median   1.000000  0.603308
# pct_ccr  0.603308  1.000000

# %%
final[['Black', 'Hispanic', 'pct_glp']].corr()
# Out:
#              Black  Hispanic   pct_glp
# Black     1.000000  0.962344  0.048690
# Hispanic  0.962344  1.000000  0.100568
# pct_glp   0.048690  0.100568  1.000000

# %%
final['school_number']=final['school_code'].astype(str).str[2:3]
charter=final[final['school_number'].str.isalpha()]
public=final[~final['school_number'].str.isalpha()]
prep=public[0:10]
notpublic= pd.merge(charter, prep, how='outer')

# %%
public
# Out:
#         FIPS          STNAME County name  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 0      37001  North Carolina    Alamance   153920     73236       80684
# 1      37001  North Carolina    Alamance   153920     73236       80684
# 2      37001  North Carolina    Alamance   153920     73236       80684
# 3      37001  North Carolina    Alamance   153920     73236       80684
# 4      37001  North Carolina    Alamance   153920     73236       80684
# 5      37001  North Carolina    Alamance   153920     73236       80684
# 6      37001  North Carolina    Alamance   153920     73236       80684
# 7      37001  North Carolina    Alamance   153920     73236       80684
# 8      37001  North Carolina    Alamance   153920     73236       80684
# 9      37001  North Carolina    Alamance   153920     73236       80684
# 10     37001  North Carolina    Alamance   153920     73236       80684
# 11     37001  North Carolina    Alamance   153920     73236       80684
# ...

# %%
public[['Black', 'Hispanic', 'pct_glp', 'pct_ccr']].corr()
# Out:
#              Black  Hispanic   pct_glp   pct_ccr
# Black     1.000000  0.961678  0.043653  0.074085
# Hispanic  0.961678  1.000000  0.096103  0.128354
# pct_glp   0.043653  0.096103  1.000000  0.986528
# pct_ccr   0.074085  0.128354  0.986528  1.000000

# %%
notpublic[['Black', 'Hispanic', 'pct_glp', 'pct_ccr','TOT_MALE','TOT_FEMALE','TOT_POP']].corr()
# Out:
#                Black  Hispanic   pct_glp   pct_ccr  TOT_MALE  TOT_FEMALE  \
# Black       1.000000  0.971552  0.047253  0.082950  0.951767    0.956166
# Hispanic    0.971552  1.000000  0.094282  0.136125  0.979301    0.980498
# pct_glp     0.047253  0.094282  1.000000  0.986823  0.129044    0.125698
# pct_ccr     0.082950  0.136125  0.986823  1.000000  0.172031    0.168477
# TOT_MALE    0.951767  0.979301  0.129044  0.172031  1.000000    0.999808
# TOT_FEMALE  0.956166  0.980498  0.125698  0.168477  0.999808    1.000000
# TOT_POP     0.954078  0.979965  0.127326  0.170208  0.999949    0.999955
#
#              TOT_POP
# Black       0.954078
# Hispanic    0.979965
# pct_glp     0.127326
# pct_ccr     0.170208
# TOT_MALE    0.999949
# TOT_FEMALE  0.999955
# TOT_POP     1.000000

# %%
public[['Black', 'Hispanic', 'pct_glp', 'pct_ccr','TOT_MALE','TOT_FEMALE','TOT_POP']].corr()
# Out:
#                Black  Hispanic   pct_glp   pct_ccr  TOT_MALE  TOT_FEMALE  \
# Black       1.000000  0.961678  0.043653  0.074085  0.954434    0.958622
# Hispanic    0.961678  1.000000  0.096103  0.128354  0.979609    0.979687
# pct_glp     0.043653  0.096103  1.000000  0.986528  0.110955    0.107390
# pct_ccr     0.074085  0.128354  0.986528  1.000000  0.145620    0.142349
# TOT_MALE    0.954434  0.979609  0.110955  0.145620  1.000000    0.999651
# TOT_FEMALE  0.958622  0.979687  0.107390  0.142349  0.999651    1.000000
# TOT_POP     0.956679  0.979735  0.109124  0.143944  0.999907    0.999918
#
#              TOT_POP
# Black       0.956679
# Hispanic    0.979735
# pct_glp     0.109124
# pct_ccr     0.143944
# TOT_MALE    0.999907
# TOT_FEMALE  0.999918
# TOT_POP     1.000000

# %%
public.nunique()
# Out:
# FIPS                  100
# STNAME                  1
# County name           100
# TOT_POP               100
# TOT_MALE              100
# TOT_FEMALE            100
# WA_MALE               100
# WA_FEMALE             100
# NHWA_MALE             100
# NHWA_FEMALE           100
# NHWhite_Alone         100
# Not_NHWhite_Alone     100
# MinorityMinority        2
# MinorityPCT           100
# Black                  99
# BlackPCT               43
# Hispanic               98
# HispanicPCT            94
# grade                   1
# num_tested           2316
# pct_ccr               866
# pct_glp               884
# school_code          2375
# subgroup                1
# subject                 1
# type                    1
# year                    5
# school_name          2268
# district_name         114
# school_number           8
# dtype: int64

# %%
notpublic.nunique()
# Out:
# FIPS                  50
# STNAME                 1
# County name           50
# TOT_POP               50
# TOT_MALE              50
# TOT_FEMALE            50
# WA_MALE               50
# WA_FEMALE             50
# NHWA_MALE             50
# NHWA_FEMALE           50
# NHWhite_Alone         50
# Not_NHWhite_Alone     50
# MinorityMinority       2
# MinorityPCT           50
# Black                 50
# BlackPCT              32
# Hispanic              49
# HispanicPCT           48
# grade                  1
# num_tested           437
# pct_ccr              359
# pct_glp              346
# school_code          107
# subgroup               1
# subject                1
# type                   1
# year                   5
# school_name          107
# district_name         50
# school_number         20
# dtype: int64

# %%
pub_all_mean2=public.groupby('County name')['pct_ccr'].agg('mean')
not_all_mean2 = notpublic.groupby('County name')['pct_ccr'].agg('mean')

# %%
stat, p = ttest_ind(pub_all_mean2, not_all_mean2)

# %%
print('Statistics=%.3f, p=%.5f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
# Out:
# Statistics=-3.515, p=0.00058
# Different distributions (reject H0)

# %%
mc = MultiComparison(info['pct_ccr'], info['status'])
result = mc.tukeyhsd()
 
print(result)
print(mc.groupsunique)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
# False   True   -7.945  -9.4871 -6.403  True
# --------------------------------------------
# [False  True]

# %% [markdown]
# So here we can reject the null hypothesis that there is no difference in mean between public and private schools, and we can also conclude that private schools have a mean pct_ccr of almost 8% higher through all years.

# %%
from statsmodels.formula.api import ols
model = ols('pct_ccr ~ pct_glp + year', info).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                pct_ccr   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                 2.232e+05
# Date:                Tue, 04 Dec 2018   Prob (F-statistic):               0.00
# Time:                        20:15:19   Log-Likelihood:                -30350.
# No. Observations:               12261   AIC:                         6.071e+04
# Df Residuals:                   12258   BIC:                         6.073e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -145.8302     37.097     -3.931      0.000    -218.546     -73.115
# ...

# %%
import statsmodels as sm

result = ols(formula='pct_ccr ~ pct_glp * status',data=info).fit()    

print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                pct_ccr   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                 1.499e+05
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):               0.00
# Time:                        09:38:51   Log-Likelihood:                -30307.
# No. Observations:               12261   AIC:                         6.062e+04
# Df Residuals:                   12257   BIC:                         6.065e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                -13.0330      0.434    -30.058      0.000     -13.883     -12.183
# ...

# %%
pub_mean2= pd.DataFrame(pub_mean)
pub_mean2['status']='pub'
len(pub_mean2)
# Out:
# 500

# %%
not_mean2= pd.DataFrame(not_mean)
not_mean2['status']='non'
len(not_mean2)
# Out:
# 250

# %%
frames=[pub_mean2, not_mean2]
comp = pd.concat(frames)
comp.head()
# Out:
#                     pct_glp status
# County name year
# Alamance    2013  48.514706    pub
#             2014  48.868571    pub
#             2015  51.562857    pub
#             2016  52.165714    pub
#             2017  50.068571    pub

# %%
mc = MultiComparison(comp['pct_glp'], comp['status'])
result = mc.tukeyhsd()
 
print(result)
print(mc.groupsunique)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower   upper  reject
# ---------------------------------------------
#  non    pub    -7.286  -9.0138 -5.5581  True
# ---------------------------------------------
# ['non' 'pub']

# %%
info[info['school_name']=='Gaston College Preparatory']
# Out:
#       grade  num_tested  pct_ccr  pct_glp school_code subgroup subject type  \
# 12084   ALL        1579     44.6     60.9      66A000      ALL     ALL  ALL
# 12085   ALL        1642     45.9     62.4      66A000      ALL     ALL  ALL
# 12086   ALL        1695     50.6     67.7      66A000      ALL     ALL  ALL
# 12087   ALL        1334     54.8     74.1      66A000      ALL     ALL  ALL
# 12088   ALL        1288     50.2     62.3      66A000      ALL     ALL  ALL
#
#        year                 school_name                       district_name  \
# 12084  2017  Gaston College Preparatory  Northampton County School District
# 12085  2016  Gaston College Preparatory  Northampton County School District
# 12086  2015  Gaston College Preparatory  Northampton County School District
# 12087  2014  Gaston College Preparatory  Northampton County School District
# 12088  2013  Gaston College Preparatory  Northampton County School District
#
#        County name  status school_number
# ...
